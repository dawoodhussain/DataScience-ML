# %%
#!pip install dlib
# !pip install face_recognition
# Out:
# Collecting face_recognition
#   Using cached https://files.pythonhosted.org/packages/3f/ed/ad9a28042f373d4633fc8b49109b623597d6f193d3bbbef7780a5ee8eef2/face_recognition-1.2.3-py2.py3-none-any.whl
# Requirement already satisfied: numpy in c:\users\msdaw\anaconda3\lib\site-packages (from face_recognition) (1.16.2)
# Collecting face-recognition-models>=0.3.0 (from face_recognition)
# Collecting dlib>=19.7 (from face_recognition)
#   Using cached https://files.pythonhosted.org/packages/05/57/e8a8caa3c89a27f80bc78da39c423e2553f482a3705adc619176a3a24b36/dlib-19.17.0.tar.gz
# Requirement already satisfied: Pillow in c:\users\msdaw\anaconda3\lib\site-packages (from face_recognition) (5.3.0)
# Requirement already satisfied: Click>=6.0 in c:\users\msdaw\anaconda3\lib\site-packages (from face_recognition) (7.0)
# Building wheels for collected packages: dlib
#   Running setup.py bdist_wheel for dlib: started
#   Running setup.py bdist_wheel for dlib: finished with status 'error'
#   Complete output from command C:\Users\msdaw\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\msdaw\\AppData\\Local\\Temp\\pip-install-yj7jqa9v\\dlib\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d C:\Users\msdaw\AppData\Local\Temp\pip-wheel-4qp2v9b1 --python-tag cp37:
#   running bdist_wheel
#   running build
#   running build_py
#   package init file 'dlib\__init__.py' not found (or not a regular file)
#   running build_ext
#   Building extension for Python 3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]
#   Invoking CMake setup: 'cmake C:\Users\msdaw\AppData\Local\Temp\pip-install-yj7jqa9v\dlib\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\msdaw\AppData\Local\Temp\pip-install-yj7jqa9v\dlib\build\lib.win-amd64-3.7 -DPYTHON_EXECUTABLE=C:\Users\msdaw\Anaconda3\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\msdaw\AppData\Local\Temp\pip-install-yj7jqa9v\dlib\build\lib.win-amd64-3.7 -A x64'
#   -- Building for: NMake Makefiles
#   CMake Error in CMakeLists.txt:
#     Generator
#
#       NMake Makefiles
#
#     does not support platform specification, but platform
#
#       x64
#
#     was specified.
#
#
#   CMake Error: CMAKE_C_COMPILER not set, after EnableLanguage
#   CMake Error: CMAKE_CXX_COMPILER not set, after EnableLanguage
#   -- Configuring incomplete, errors occurred!
#   See also "C:/Users/msdaw/AppData/Local/Temp/pip-install-yj7jqa9v/dlib/build/temp.win-amd64-3.7/Release/CMakeFiles/CMakeOutput.log".
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\msdaw\AppData\Local\Temp\pip-install-yj7jqa9v\dlib\setup.py", line 261, in <module>
#       'Topic :: Software Development',
#     File "C:\Users\msdaw\Anaconda3\lib\site-packages\setuptools\__init__.py", line 143, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\msdaw\Anaconda3\lib\distutils\core.py", line 148, in setup
#       dist.run_commands()
#     File "C:\Users\msdaw\Anaconda3\lib\distutils\dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\msdaw\Anaconda3\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\msdaw\Anaconda3\lib\site-packages\wheel\bdist_wheel.py", line 188, in run
#       self.run_command('build')
#     File "C:\Users\msdaw\Anaconda3\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\msdaw\Anaconda3\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\msdaw\Anaconda3\lib\distutils\command\build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "C:\Users\msdaw\Anaconda3\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\msdaw\Anaconda3\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\msdaw\AppData\Local\Temp\pip-install-yj7jqa9v\dlib\setup.py", line 135, in run
#       self.build_extension(ext)
#     File "C:\Users\msdaw\AppData\Local\Temp\pip-install-yj7jqa9v\dlib\setup.py", line 172, in build_extension
#       subprocess.check_call(cmake_setup, cwd=build_folder)
#     File "C:\Users\msdaw\Anaconda3\lib\subprocess.py", line 341, in check_call
#       raise CalledProcessError(retcode, cmd)
#   subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\msdaw\\AppData\\Local\\Temp\\pip-install-yj7jqa9v\\dlib\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\msdaw\\AppData\\Local\\Temp\\pip-install-yj7jqa9v\\dlib\\build\\lib.win-amd64-3.7', '-DPYTHON_EXECUTABLE=C:\\Users\\msdaw\\Anaconda3\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\msdaw\\AppData\\Local\\Temp\\pip-install-yj7jqa9v\\dlib\\build\\lib.win-amd64-3.7', '-A', 'x64']' returned non-zero exit status 1.
#
#   ----------------------------------------
#   Running setup.py clean for dlib
# Failed to build dlib
# Installing collected packages: face-recognition-models, dlib, face-recognition
#   Running setup.py install for dlib: started
#     Running setup.py install for dlib: finished with status 'error'
#     Complete output from command C:\Users\msdaw\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\msdaw\\AppData\\Local\\Temp\\pip-install-yj7jqa9v\\dlib\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record C:\Users\msdaw\AppData\Local\Temp\pip-record-96nq915b\install-record.txt --single-version-externally-managed --compile:
#     running install
#     running build
#     running build_py
#     package init file 'dlib\__init__.py' not found (or not a regular file)
#     running build_ext
#     Building extension for Python 3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]
#     Invoking CMake setup: 'cmake C:\Users\msdaw\AppData\Local\Temp\pip-install-yj7jqa9v\dlib\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\msdaw\AppData\Local\Temp\pip-install-yj7jqa9v\dlib\build\lib.win-amd64-3.7 -DPYTHON_EXECUTABLE=C:\Users\msdaw\Anaconda3\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\msdaw\AppData\Local\Temp\pip-install-yj7jqa9v\dlib\build\lib.win-amd64-3.7 -A x64'
#     -- Building for: NMake Makefiles
#     CMake Error in CMakeLists.txt:
#       Generator
#
#         NMake Makefiles
#
#       does not support platform specification, but platform
#
#         x64
#
#       was specified.
#
#
#     CMake Error: CMAKE_C_COMPILER not set, after EnableLanguage
#     CMake Error: CMAKE_CXX_COMPILER not set, after EnableLanguage
#     -- Configuring incomplete, errors occurred!
#     See also "C:/Users/msdaw/AppData/Local/Temp/pip-install-yj7jqa9v/dlib/build/temp.win-amd64-3.7/Release/CMakeFiles/CMakeOutput.log".
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\msdaw\AppData\Local\Temp\pip-install-yj7jqa9v\dlib\setup.py", line 261, in <module>
#         'Topic :: Software Development',
#       File "C:\Users\msdaw\Anaconda3\lib\site-packages\setuptools\__init__.py", line 143, in setup
#         return distutils.core.setup(**attrs)
#       File "C:\Users\msdaw\Anaconda3\lib\distutils\core.py", line 148, in setup
#         dist.run_commands()
#       File "C:\Users\msdaw\Anaconda3\lib\distutils\dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "C:\Users\msdaw\Anaconda3\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\msdaw\Anaconda3\lib\site-packages\setuptools\command\install.py", line 61, in run
#         return orig.install.run(self)
#       File "C:\Users\msdaw\Anaconda3\lib\distutils\command\install.py", line 545, in run
#         self.run_command('build')
#       File "C:\Users\msdaw\Anaconda3\lib\distutils\cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "C:\Users\msdaw\Anaconda3\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\msdaw\Anaconda3\lib\distutils\command\build.py", line 135, in run
#         self.run_command(cmd_name)
#       File "C:\Users\msdaw\Anaconda3\lib\distutils\cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "C:\Users\msdaw\Anaconda3\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\msdaw\AppData\Local\Temp\pip-install-yj7jqa9v\dlib\setup.py", line 135, in run
#         self.build_extension(ext)
#       File "C:\Users\msdaw\AppData\Local\Temp\pip-install-yj7jqa9v\dlib\setup.py", line 172, in build_extension
#         subprocess.check_call(cmake_setup, cwd=build_folder)
#       File "C:\Users\msdaw\Anaconda3\lib\subprocess.py", line 341, in check_call
#         raise CalledProcessError(retcode, cmd)
#     subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\msdaw\\AppData\\Local\\Temp\\pip-install-yj7jqa9v\\dlib\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\msdaw\\AppData\\Local\\Temp\\pip-install-yj7jqa9v\\dlib\\build\\lib.win-amd64-3.7', '-DPYTHON_EXECUTABLE=C:\\Users\\msdaw\\Anaconda3\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\msdaw\\AppData\\Local\\Temp\\pip-install-yj7jqa9v\\dlib\\build\\lib.win-amd64-3.7', '-A', 'x64']' returned non-zero exit status 1.
#
#     ----------------------------------------
#   Failed building wheel for dlib
# Command "C:\Users\msdaw\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\msdaw\\AppData\\Local\\Temp\\pip-install-yj7jqa9v\\dlib\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record C:\Users\msdaw\AppData\Local\Temp\pip-record-96nq915b\install-record.txt --single-version-externally-managed --compile" failed with error code 1 in C:\Users\msdaw\AppData\Local\Temp\pip-install-yj7jqa9v\dlib\

# %%
# !pip install CMake
# Out:
# Collecting CMake
#   Downloading https://files.pythonhosted.org/packages/17/a7/6026f6bca7cef489617e4f8bdfdade2534ae27bfa514d3731dce29496969/cmake-3.13.3-cp37-cp37m-win_amd64.whl (29.4MB)
# Installing collected packages: CMake
# Successfully installed CMake-3.13.3

# %%
# import the libraries
import os
import face_recognition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-e6a4bcb79589> in <module>
#       1 # import the libraries
#       2 import os
# ----> 3 import face_recognition
#
# ModuleNotFoundError: No module named 'face_recognition'

# %%
# !pip install dlib
# Out:
# Collecting dlib
#   Using cached https://files.pythonhosted.org/packages/05/57/e8a8caa3c89a27f80bc78da39c423e2553f482a3705adc619176a3a24b36/dlib-19.17.0.tar.gz
# Building wheels for collected packages: dlib
#   Running setup.py bdist_wheel for dlib: started
#   Running setup.py bdist_wheel for dlib: finished with status 'error'
#   Complete output from command C:\Users\msdaw\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\msdaw\\AppData\\Local\\Temp\\pip-install-ftw55rx4\\dlib\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d C:\Users\msdaw\AppData\Local\Temp\pip-wheel-w6beetrd --python-tag cp37:
#   running bdist_wheel
#   running build
#   running build_py
#   package init file 'dlib\__init__.py' not found (or not a regular file)
#   running build_ext
#   Building extension for Python 3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]
#   Invoking CMake setup: 'cmake C:\Users\msdaw\AppData\Local\Temp\pip-install-ftw55rx4\dlib\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\msdaw\AppData\Local\Temp\pip-install-ftw55rx4\dlib\build\lib.win-amd64-3.7 -DPYTHON_EXECUTABLE=C:\Users\msdaw\Anaconda3\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\msdaw\AppData\Local\Temp\pip-install-ftw55rx4\dlib\build\lib.win-amd64-3.7 -A x64'
#   -- Building for: NMake Makefiles
#   CMake Error in CMakeLists.txt:
#     Generator
#
#       NMake Makefiles
#
#     does not support platform specification, but platform
#
#       x64
#
#     was specified.
#
#
#   CMake Error: CMAKE_C_COMPILER not set, after EnableLanguage
#   CMake Error: CMAKE_CXX_COMPILER not set, after EnableLanguage
#   -- Configuring incomplete, errors occurred!
#   See also "C:/Users/msdaw/AppData/Local/Temp/pip-install-ftw55rx4/dlib/build/temp.win-amd64-3.7/Release/CMakeFiles/CMakeOutput.log".
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\msdaw\AppData\Local\Temp\pip-install-ftw55rx4\dlib\setup.py", line 261, in <module>
#       'Topic :: Software Development',
#     File "C:\Users\msdaw\Anaconda3\lib\site-packages\setuptools\__init__.py", line 143, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\msdaw\Anaconda3\lib\distutils\core.py", line 148, in setup
#       dist.run_commands()
#     File "C:\Users\msdaw\Anaconda3\lib\distutils\dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\msdaw\Anaconda3\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\msdaw\Anaconda3\lib\site-packages\wheel\bdist_wheel.py", line 188, in run
#       self.run_command('build')
#     File "C:\Users\msdaw\Anaconda3\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\msdaw\Anaconda3\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\msdaw\Anaconda3\lib\distutils\command\build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "C:\Users\msdaw\Anaconda3\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\msdaw\Anaconda3\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\msdaw\AppData\Local\Temp\pip-install-ftw55rx4\dlib\setup.py", line 135, in run
#       self.build_extension(ext)
#     File "C:\Users\msdaw\AppData\Local\Temp\pip-install-ftw55rx4\dlib\setup.py", line 172, in build_extension
#       subprocess.check_call(cmake_setup, cwd=build_folder)
#     File "C:\Users\msdaw\Anaconda3\lib\subprocess.py", line 341, in check_call
#       raise CalledProcessError(retcode, cmd)
#   subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\msdaw\\AppData\\Local\\Temp\\pip-install-ftw55rx4\\dlib\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\msdaw\\AppData\\Local\\Temp\\pip-install-ftw55rx4\\dlib\\build\\lib.win-amd64-3.7', '-DPYTHON_EXECUTABLE=C:\\Users\\msdaw\\Anaconda3\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\msdaw\\AppData\\Local\\Temp\\pip-install-ftw55rx4\\dlib\\build\\lib.win-amd64-3.7', '-A', 'x64']' returned non-zero exit status 1.
#
#   ----------------------------------------
#   Running setup.py clean for dlib
# Failed to build dlib
# Installing collected packages: dlib
#   Running setup.py install for dlib: started
#     Running setup.py install for dlib: finished with status 'error'
#     Complete output from command C:\Users\msdaw\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\msdaw\\AppData\\Local\\Temp\\pip-install-ftw55rx4\\dlib\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record C:\Users\msdaw\AppData\Local\Temp\pip-record-1q47tgb9\install-record.txt --single-version-externally-managed --compile:
#     running install
#     running build
#     running build_py
#     package init file 'dlib\__init__.py' not found (or not a regular file)
#     running build_ext
#     Building extension for Python 3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)]
#     Invoking CMake setup: 'cmake C:\Users\msdaw\AppData\Local\Temp\pip-install-ftw55rx4\dlib\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\msdaw\AppData\Local\Temp\pip-install-ftw55rx4\dlib\build\lib.win-amd64-3.7 -DPYTHON_EXECUTABLE=C:\Users\msdaw\Anaconda3\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\msdaw\AppData\Local\Temp\pip-install-ftw55rx4\dlib\build\lib.win-amd64-3.7 -A x64'
#     -- Building for: NMake Makefiles
#     CMake Error in CMakeLists.txt:
#       Generator
#
#         NMake Makefiles
#
#       does not support platform specification, but platform
#
#         x64
#
#       was specified.
#
#
#     CMake Error: CMAKE_C_COMPILER not set, after EnableLanguage
#     CMake Error: CMAKE_CXX_COMPILER not set, after EnableLanguage
#     -- Configuring incomplete, errors occurred!
#     See also "C:/Users/msdaw/AppData/Local/Temp/pip-install-ftw55rx4/dlib/build/temp.win-amd64-3.7/Release/CMakeFiles/CMakeOutput.log".
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\msdaw\AppData\Local\Temp\pip-install-ftw55rx4\dlib\setup.py", line 261, in <module>
#         'Topic :: Software Development',
#       File "C:\Users\msdaw\Anaconda3\lib\site-packages\setuptools\__init__.py", line 143, in setup
#         return distutils.core.setup(**attrs)
#       File "C:\Users\msdaw\Anaconda3\lib\distutils\core.py", line 148, in setup
#         dist.run_commands()
#       File "C:\Users\msdaw\Anaconda3\lib\distutils\dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "C:\Users\msdaw\Anaconda3\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\msdaw\Anaconda3\lib\site-packages\setuptools\command\install.py", line 61, in run
#         return orig.install.run(self)
#       File "C:\Users\msdaw\Anaconda3\lib\distutils\command\install.py", line 545, in run
#         self.run_command('build')
#       File "C:\Users\msdaw\Anaconda3\lib\distutils\cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "C:\Users\msdaw\Anaconda3\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\msdaw\Anaconda3\lib\distutils\command\build.py", line 135, in run
#         self.run_command(cmd_name)
#       File "C:\Users\msdaw\Anaconda3\lib\distutils\cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "C:\Users\msdaw\Anaconda3\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\msdaw\AppData\Local\Temp\pip-install-ftw55rx4\dlib\setup.py", line 135, in run
#         self.build_extension(ext)
#       File "C:\Users\msdaw\AppData\Local\Temp\pip-install-ftw55rx4\dlib\setup.py", line 172, in build_extension
#         subprocess.check_call(cmake_setup, cwd=build_folder)
#       File "C:\Users\msdaw\Anaconda3\lib\subprocess.py", line 341, in check_call
#         raise CalledProcessError(retcode, cmd)
#     subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\msdaw\\AppData\\Local\\Temp\\pip-install-ftw55rx4\\dlib\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\msdaw\\AppData\\Local\\Temp\\pip-install-ftw55rx4\\dlib\\build\\lib.win-amd64-3.7', '-DPYTHON_EXECUTABLE=C:\\Users\\msdaw\\Anaconda3\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\msdaw\\AppData\\Local\\Temp\\pip-install-ftw55rx4\\dlib\\build\\lib.win-amd64-3.7', '-A', 'x64']' returned non-zero exit status 1.
#
#     ----------------------------------------
#   Failed building wheel for dlib
# Command "C:\Users\msdaw\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\msdaw\\AppData\\Local\\Temp\\pip-install-ftw55rx4\\dlib\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record C:\Users\msdaw\AppData\Local\Temp\pip-record-1q47tgb9\install-record.txt --single-version-externally-managed --compile" failed with error code 1 in C:\Users\msdaw\AppData\Local\Temp\pip-install-ftw55rx4\dlib\

# %%
# !pip install https://pypi.python.org/packages/da/06/bd3e241c4eb0a662914b3b4875fc52dd176a9db0d4a2c915ac2ad8800e9e/dlib-19.7.0-cp36-cp36m-win_amd64.whl#md5=b7330a5b2d46420343fbed5df69e6a3f
# Out:
# dlib-19.7.0-cp36-cp36m-win_amd64.whl is not a supported wheel on this platform.
